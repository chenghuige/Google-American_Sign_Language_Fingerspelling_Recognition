# %%
import sys
sys.path.append('/work/pikachu/utils/')
sys.path.append('/work/pikachu/third/')
sys.path.append('..')
from gezi.common import *
import gezi
from src.config import *
from src.util import *
gezi.init_flags()
# Out:
# INFO: Pandarallel will run on 16 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# [07/14/23 15:59:27] config.py:124 in <module>- N_COLS: 184
# [07/14/23 15:59:27] config.py:144 in <module>- VOCAB_SIZE: 65
# [07/14/23 15:59:27] config.py:145 in <module>- len(IDX2CHAR): 65

# %%
# created by prepare/gen-df.py
train = pd.read_feather(f'{FLAGS.root}/train.fea')
train.head(5)
# Out:
#    index                                             frames    file_id  fold  \
# 0      0  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...  234418913     1
# 1      1  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...  234418913     1
# 2      2  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...  234418913     1
# 3      3  [[0.679081, 0.62824833, 0.5867444, 0.55760944,...  234418913     1
# 4      4  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...  234418913     1
#
#     idx  n_frames  n_frames_per_char  participant_id               phrase  \
# 0  1891       135           9.642858             202       +39-691-02-830
# 1  1963       107          10.700000              36           ruth gibbs
# 2  1806       103           7.357143             141       59 dodds creek
# 3  1857       151          11.615385             154        darrell simon
# 4  2025       154           8.105263             202  +976-2297-742-44-88
#
# ...

# %%
df = train[train.fold==0]
df = df.sort_values(by=['idx'], ascending=True)
df.head(5)
# Out:
#        index                                             frames  file_id  \
# 22341  22341  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...  5414471
# 22209  22209  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...  5414471
# 22320  22320  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...  5414471
# 22180  22180  [[0.9317963, 0.8649128, 0.80721205, 0.7606563,...  5414471
# 22178  22178  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...  5414471
#
#        fold  idx  n_frames  n_frames_per_char  participant_id  \
# 22341     0    0       127           8.466666             107
# 22209     0    1       236          12.421053               1
# 22320     0    2       300          13.636364              70
# 22180     0    3       120           8.571428              20
# 22178     0    4       182           9.100000             254
#
#                        phrase  \
# 22341         scales/kuhaylah
# 22209     1383 william lanier
# 22320  https://jsi.is/hukuoka
# ...

# %%
V = 9
fold = 0
model = 'v20.model-model2.task-encode.n_frames-256.encode_pool_size-4.ep-100'
root = f'../working/offline/{V}/{fold}/{model}'
root
# Out:
# '../working/offline/9/0/v20.model-model2.task-encode.n_frames-256.encode_pool_size-4.ep-100'

# %%
ev_df = pd.read_csv(f'{root}/eval.csv')
ev_df
# Out:
#     sequence_id phrase_type  phrase_dup                     phrase_true  \
# 0    1816825349         url           0                 scales/kuhaylah
# 1    1816909464     address           1             1383 william lanier
# 2    1817169529         url           1          https://jsi.is/hukuoka
# 3    1817348598     address           1                  wildberries_ru
# 4    1817606833     address           1            6867 granville drive
# 5    1817770333     address           1                 166 water power
# 6    1818125771         url           1      www.theorienttreasures.com
# 7    1818160881     address           1                 9345 happy dirt
# 8    1818216000     address           1            5126 whitewind drive
# 9    1818246565       phone           0                    893-125-1663
# 10   1818249176     address           0         4821 holly ridge circle
# 11   1818252449       phone           0                    106-703-4104
# ...

# %%
ev_df.iloc[0].phrase_ori
# Out:
# '<PAD>ss<PAD>eaalleess<PAD>//<PAD><PAD>kk<PAD>uu<PAD>h<PAD>aayyllaa<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><EOS><EOS><EOS><EOS><EOS><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>'
